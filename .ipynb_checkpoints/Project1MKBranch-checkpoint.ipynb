# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import requests
from pprint import pprint
from pandas import json_normalize
import json
# Import API key
from config import apikey
from config import app_ID

# %%
district_list = []
states = ["GA", "AL", "MS", "SC", "FL", "LS", "TN", "NC"]

for state in states:
    url = "https://api.schooldigger.com/v1.2/districts?st="
    query_start_url = f"{url}"
    query_end_url = f"&page=1&perPage=50&appID={app_ID}&appKey={apikey}"
    path = query_start_url + state + query_end_url
    district_req = requests.get(path)
    district_json = district_req.json()
    if 'districtList' in district_json:
        district_list.extend(district_json['districtList'])

# %%
districtName = []
county_list = []
city_list = []
numbertotalschools = []
number_primary_schools = []
number_middle_schools = []
number_high_schools = []
number_alternative_schools = []
state_list = []
rank = []
rankOf = []
rankStatewidePercentage = []
year = []
zip_code = []

for item in district_list:
    districtName.append(item.get('districtName'))
    county_list.append(item.get('county').get('countyName'))
    city_list.append(item.get('address').get('city'))
    numbertotalschools.append(item.get('numberTotalSchools'))
    number_primary_schools.append(item.get('numberPrimarySchools'))
    number_middle_schools.append(item.get('numberMiddleSchools'))
    number_high_schools.append(item.get('numberHighSchools'))
    number_alternative_schools.append(item.get('numberAlternativeSchools'))
    state_list.append(item.get('address').get('state'))
    zip_code.append(item.get('address').get('zip'))
    if item['rankHistory']:
        rank.append(item['rankHistory'][0]['rank'])
        rankOf.append(item['rankHistory'][0]['rankOf'])
        rankStatewidePercentage.append(item['rankHistory'][0]['rankStatewidePercentage'])
        year.append(item['rankHistory'][0]['year'])
    else: 
        rank.append('')
        rankOf.append('')
        rankStatewidePercentage.append('')
        year.append('')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-169-dc1f4aaee4df> in <module>
#      26     zip_code.append(item.get('address').get('zip'))
#      27     if item['rankHistory']:
# ---> 28         rank.append(item['rankHistory'][1]['rank'])
#      29         rankOf.append(item['rankHistory'][1]['rankOf'])
#      30         rankStatewidePercentage.append(item['rankHistory'][1]['rankStatewidePercentage'])
#
# IndexError: list index out of range

# %%
print(len(districtName))
print(len(county_list))
print(len(city_list))
print(len(numbertotalschools))
print(len(number_primary_schools))
print(len(number_middle_schools))
print(len(number_high_schools))
print(len(number_alternative_schools))
print(len(state_list))
print(len(rank))
print(len(rankOf))
print(len(rankStatewidePercentage))
print(len(year))
print(len(zip_code))
# Out:
# 343
# 343
# 343
# 343
# 343
# 343
# 343
# 343
# 343
# 343
# 343
# 343
# 343
# 343

# %%
district_dict = {
    "City": city_list,
    "County": county_list,
    "District Name": districtName,
    "Number of High Schools": number_high_schools,
    "Number of Middle Schools": number_middle_schools,
    "Number of Alternative Schools": number_alternative_schools,
    "Number of Primary Schools": number_primary_schools,
    "Number of Total Schools": numbertotalschools,
    "State": state_list,
    "Rank": rank,
    "RankOf": rankOf,
    "RankStatewidePercentage": rankStatewidePercentage,
    "Year": year,
    "Zip Code": zip_code
}
district_data = pd.DataFrame(district_dict)
district_data
# Out:
#             City    County                   District Name  \
# 0         Baxley   Appling                  Appling County
# 1        Pearson  Atkinson                 Atkinson County
# 2        Atlanta    Fulton          Atlanta Public Schools
# 3           Alma     Bacon                    Bacon County
# 4         Newton     Baker                    Baker County
# ..           ...       ...                             ...
# 338     Beaufort  Carteret  Carteret County Public Schools
# 339      Raleigh      Wake       Casa Esperanza Montessori
# 340  Yanceyville   Caswell          Caswell County Schools
# 341        Sylva   Jackson                Catamount School
# 342       Newton   Catawba          Catawba County Schools
#
#      Number of High Schools  Number of Middle Schools  \
# 0                         1                         1
# 1                         1                         1
# 2                        16                        15
# 3                         1                         1
# 4                         0                         0
# ..                      ...                       ...
# 338                       4                         4
# 339                       0                         0
# 340                       1                         1
# 341                       0                         1
# 342                       6                         5
#
#      Number of Alternative Schools  Number of Primary Schools  \
# 0                                0                          4
# 1                                0                          2
# 2                                2                         56
# 3                                0                          2
# 4                                1                          0
# ..                             ...                        ...
# 338                              1                          9
# 339                              0                          1
# 340                              0                          4
# 341                              0                          0
# 342                              1                         16
#
#      Number of Total Schools State Rank RankOf RankStatewidePercentage  Year  \
# 0                          6    GA   88    196                    55.1  2019
# 1                          4    GA   75    196                   61.73  2019
# 2                         89    GA  136    196                   30.61  2019
# 3                          4    GA   85    196                   56.63  2019
# 4                          1    GA
# ..                       ...   ...  ...    ...                     ...   ...
# 338                       18    NC   38    242                    84.3  2019
# 339                        1    NC   87    242                   64.05  2019
# 340                        6    NC  186    242                   23.14  2019
# 341                        1    NC  151    242                    37.6  2019
# 342                       28    NC   80    242                   66.94  2019
#
#     Zip Code
# 0      31513
# 1      31642
# 2      30335
# 3      31510
# 4      31770
# ..       ...
# 338    28516
# 339    27616
# 340    27379
# 341    28779
# 342    28658
#
# [343 rows x 14 columns]

# %%
district_data.to_csv("District Data/district_data.csv")
