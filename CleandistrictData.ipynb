# %%
# Dependencies
import pandas as pd

# %%
# Store filepath in a variable
districtdata = pd.read_csv("District Data/district_data.csv")

# %%
districtdata
# Out:
#      Unnamed: 0         City    County                   District Name  \
# 0             0       Baxley   Appling                  Appling County
# 1             1      Pearson  Atkinson                 Atkinson County
# 2             2      Atlanta    Fulton          Atlanta Public Schools
# 3             3         Alma     Bacon                    Bacon County
# 4             4       Newton     Baker                    Baker County
# ..          ...          ...       ...                             ...
# 338         338     Beaufort  Carteret  Carteret County Public Schools
# 339         339      Raleigh      Wake       Casa Esperanza Montessori
# 340         340  Yanceyville   Caswell          Caswell County Schools
# 341         341        Sylva   Jackson                Catamount School
# 342         342       Newton   Catawba          Catawba County Schools
#
#      Number of High Schools  Number of Middle Schools  \
# 0                         1                         1
# ...

# %%
# Identify incomplete rows
districtdata.count()
# Out:
# Unnamed: 0                       343
# City                             343
# County                           343
# District Name                    343
# Number of High Schools           343
# Number of Middle Schools         343
# Number of Alternative Schools    343
# Number of Primary Schools        343
# Number of Total Schools          343
# State                            343
# Rank                             305
# RankOf                           305
# RankStatewidePercentage          305
# Year                             305
# Zip Code                         343
# dtype: int64

# %%
# sort by county
county_df = districtdata.sort_values(
    ["County"], ascending=True)
county_df.head(20)
# Out:
#      Unnamed: 0          City     County                 District Name  \
# 149         149     Abbeville  Abbeville                  Abbeville 60
# 150         150         Aiken      Aiken                      Aiken 01
# 199         199   Gainesville    Alachua                       Alachua
# 300         300    Burlington   Alamance   Alamance-Burlington Schools
# 101         101       Corinth     Alcorn        Alcorn School District
# 127         127       Corinth     Alcorn       Corinth School District
# 301         301  Taylorsville  Alexander      Alexander County Schools
# 302         302        Sparta  Alleghany      Alleghany County Schools
# 151         151       Fairfax  Allendale                  Allendale 01
# 102         102       Liberty      Amite  Amite County School District
# 274         274       Clinton   Anderson                       Clinton
# 253         253       Clinton   Anderson               Anderson County
# ...

# %%
# The index can be reset
new_index_df = county_df.set_index('County',drop=True)
new_index_df
# Out:
#             Unnamed: 0         City                District Name  \
# County
# Abbeville          149    Abbeville                 Abbeville 60
# Aiken              150        Aiken                     Aiken 01
# Alachua            199  Gainesville                      Alachua
# Alamance           300   Burlington  Alamance-Burlington Schools
# Alcorn             101      Corinth       Alcorn School District
# ...                ...          ...                          ...
# Walker              33  Chickamauga             Chickamauga City
# Washington         140   Greenville    Greenville Public Schools
# Wilkes             325   State Road              Bridges Academy
# Williamson         293     Franklin                 Franklin SSD
# Yalobusha          123  Coffeeville  Coffeeville School District
#
#             Number of High Schools  Number of Middle Schools  \
# County
# Abbeville                        3                         1
# ...
